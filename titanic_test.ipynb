# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("titanic.csv")
plt.ylabel('Age')
plt.xlabel('Fare')
# 绘制散点图
plt.scatter(df['Fare'], df['Age'], c=df['Survived'])

# 构造二元一次方程
y = np.arange(0, 80, 1)
c = 30
x = y + c


# 绘制直线
plt.plot(x, y, 'c')
